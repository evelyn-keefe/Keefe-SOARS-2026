# %%
# %run utils/difference_plot_module.ipynb
import xarray as xr
import pandas as pd
import numpy as np
import os

# %%
input_path = '/glade/work/ekeefe/research_code/model_output/historical_sim'
hist_run = create_big_ds(input_path)
# Out:
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_87378/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')

# %%
aunz = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_aunz_output')
bona = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_bona_output')
tena = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_tena_output')
# Out:
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_87378/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_87378/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_87378/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')

# %%
# %run utils/timeseries_module.ipynb

# %%
pm_concentration_ts(hist_run, aunz, bona, tena)

# %%
# %run utils/percent_contribution.ipynb

# %%
all_sfc_pm_pc(hist_run, aunz, bona, tena, table=True)
# Out:
#                 AUNZ
# Date                         Percent (%)
# 2014-12-01           0.07948573678731918
# 2015-03-01          -0.47850409150123596
# 2015-06-01           -0.8827996253967285
# 2015-09-01            1.1765072345733643
# 2015-12-01          -0.08820479363203049
# 2016-03-01           -0.4057055711746216
# 2016-06-01           -0.3821738064289093
# 2016-09-01            0.6405928730964661
# 2016-12-01           0.08573070168495178
# 2017-03-01          -0.03698623180389404
# 2017-06-01           -0.5429649353027344
# 2017-09-01             1.334132194519043
# 2017-12-01            0.2863999605178833
# 2018-03-01          -0.11400658637285233
# 2018-06-01           -0.2564453184604645
# 2018-09-01            1.2092092037200928
# 2018-12-01           0.27198371291160583
# 2019-03-01          -0.09127490967512131
# 2019-06-01             -0.67757248878479
# 2019-09-01            1.6953682899475098
# 2019-12-01            2.1103768348693848
#
#
#                 BONA
# Date                         Percent (%)
# 2014-12-01          -0.11955064535140991
# 2015-03-01          -0.06960012763738632
# 2015-06-01           0.33319801092147827
# 2015-09-01            0.8526318073272705
# 2015-12-01          -0.17200087010860443
# 2016-03-01           -0.3314262926578522
# 2016-06-01            -0.195527583360672
# 2016-09-01            0.5543434619903564
# 2016-12-01            0.1390398144721985
# 2017-03-01           -0.2271256446838379
# 2017-06-01            0.8199029564857483
# 2017-09-01            1.0754605531692505
# 2017-12-01            0.2725154161453247
# 2018-03-01           -0.3127005994319916
# 2018-06-01             0.354026734828949
# 2018-09-01            0.7768853306770325
# 2018-12-01           -0.2273840606212616
# 2019-03-01            0.1568058282136917
# 2019-06-01          -0.13632294535636902
# 2019-09-01            0.8806105852127075
# 2019-12-01           -0.3669658303260803
#
#
#                 TENA
# Date                         Percent (%)
# 2014-12-01          -0.014665143564343452
# 2015-03-01           -0.4846632480621338
# 2015-06-01           -0.7544854879379272
# 2015-09-01            0.6913280487060547
# 2015-12-01          -0.09875200688838959
# 2016-03-01           -0.2727942168712616
# 2016-06-01          -0.23607966303825378
# 2016-09-01            0.5375587344169617
# 2016-12-01           0.22913983464241028
# 2017-03-01           0.05676222965121269
# 2017-06-01            -0.518325924873352
# 2017-09-01            1.0411354303359985
# 2017-12-01           0.49819350242614746
# 2018-03-01           -0.1451139897108078
# 2018-06-01          -0.08669485151767731
# 2018-09-01            0.8238205909729004
# 2018-12-01          -0.14937655627727509
# 2019-03-01          0.049827348440885544
# 2019-06-01           -0.7707501649856567
# 2019-09-01            0.8867897987365723
# 2019-12-01           -0.3295398950576782
