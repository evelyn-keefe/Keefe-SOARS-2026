# %%
import xarray as xr
import pandas as pd
import numpy as np
import os
# %run utils/difference_plot_module.ipynb

# %%
# Create datasets
hist = create_big_ds('/glade/work/ekeefe/research_code/model_output/historical_sim')
aunz = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_aunz_output')
bona = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_bona_output')
tena = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_tena_output')
# Out:
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_50118/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')
# ...

# %%
# Run spatial ozone difference plots for each region over the whole study period 
sfc_spatial_diff_plot(hist, aunz, 'aunz', 'ozone')
# Out:
# -2.8150587

# %%
sfc_spatial_diff_plot(hist, bona, 'bona', 'ozone')
# Out:
# -2.5452359

# %%
sfc_spatial_diff_plot(hist, tena, 'tena', 'ozone')
# Out:
# -2.88679

# %%
# Run spatial PM2.5 difference plots for each region over the whole study period
sfc_spatial_diff_plot(hist, aunz, 'aunz', 'PM25')
# Out:
# 3.430816

# %%
sfc_spatial_diff_plot(hist, bona, 'bona', 'PM25')
# Out:
# 3.430816

# %%
sfc_spatial_diff_plot(hist, tena, 'tena', 'PM25')
# Out:
# 3.430816

# %%
# Create seasonal difference timeseries
# %run utils/timeseries_module.ipynb

# %%
difference_ts(hist, aunz, bona, tena, 'ozone')

# %%
difference_ts(hist, aunz, bona, tena, 'PM25')
