# %%
import xarray as xr
import pandas as pd
import numpy as np
import os
# %run helper_funcs.ipynb
# %run utils/timeseries_module.ipynb

# %%
# Create datasets
hist = create_big_ds('/glade/work/ekeefe/research_code/model_output/historical_sim')
aunz = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_aunz_output')
bona = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_bona_output')
tena = create_big_ds('/glade/work/ekeefe/research_code/model_output/proper_output/proper_tena_output')
# Out:
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_82138/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_82138/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_82138/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')
# /glade/derecho/scratch/ekeefe/tmp/ipykernel_82138/3957096376.py:22: FutureWarning: In a future version of xarray the default value for data_vars will change from data_vars='all' to data_vars=None. This is likely to lead to different results when multiple datasets have matching variables with overlapping values. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set data_vars explicitly.
#   big_ds = xr.open_mfdataset(files, compat='override', coords='minimal', engine='netcdf4')

# %%
# Create time series of global pollutant concentrations
ozone_concentration_ts(hist, aunz, bona, tena)

# %%
# Create a percent contribution plot and table
# %run utils/percent_contribution.ipynb
all_sfc_ozone_pc(hist, aunz, bona, tena, table=True)
# Out:
#                 AUNZ
# Date                         Percent (%)
# 2014-12-01                    0.15337363
# 2015-03-01                   0.026644673
# 2015-06-01                    0.32950157
# 2015-09-01                     1.3638457
# 2015-12-01                     0.7395387
# 2016-03-01                    -0.0216811
# 2016-06-01                    0.46521923
# 2016-09-01                     0.8154106
# 2016-12-01                    0.52205634
# 2017-03-01                      0.272265
# 2017-06-01                   -0.12332937
# 2017-09-01                     1.7809415
# 2017-12-01                     1.0866472
# 2018-03-01                    0.13760555
# 2018-06-01                    0.35079136
# 2018-09-01                     1.5712681
# 2018-12-01                    0.96920645
# 2019-03-01                    0.19453754
# 2019-06-01                   0.044419512
# 2019-09-01                     1.3175347
# 2019-12-01                     1.9347813
#
#
#                 BONA
# Date                         Percent (%)
# 2014-12-01                  -0.047386922
# 2015-03-01                   -0.10475901
# 2015-06-01                     1.5459583
# 2015-09-01                      0.659611
# 2015-12-01                    0.51770043
# 2016-03-01                   -0.15603736
# 2016-06-01                     0.3827817
# 2016-09-01                    0.41941008
# 2016-12-01                    0.22567865
# 2017-03-01                  -0.029255625
# 2017-06-01                    0.20684174
# 2017-09-01                     1.3551403
# 2017-12-01                    0.34372595
# 2018-03-01                   -0.22129917
# 2018-06-01                    0.09465636
# 2018-09-01                    0.75602186
# 2018-12-01                     0.2361135
# 2019-03-01                    0.13272291
# 2019-06-01                    0.37259752
# 2019-09-01                      0.587951
# 2019-12-01                    0.02902135
#
#
#                 TENA
# Date                         Percent (%)
# 2014-12-01                   -0.06159069
# 2015-03-01                   -0.17537402
# 2015-06-01                   -0.19754913
# 2015-09-01                     0.4658225
# 2015-12-01                    0.46947473
# 2016-03-01                  -0.008608166
# 2016-06-01                    0.05805147
# 2016-09-01                    0.40475246
# 2016-12-01                    0.26601654
# 2017-03-01                    0.16287103
# 2017-06-01                   -0.65170187
# 2017-09-01                    0.77879643
# 2017-12-01                    0.33461085
# 2018-03-01                  -0.102726996
# 2018-06-01                   -0.14753926
# 2018-09-01                     0.5783129
# 2018-12-01                    0.21968874
# 2019-03-01                   -0.07908702
# 2019-06-01                   -0.42106578
# 2019-09-01                     0.4753434
# 2019-12-01                   0.012324474
